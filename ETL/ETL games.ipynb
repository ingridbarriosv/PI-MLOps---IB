# %% [markdown]
# # ETL Steam Games

# %%
import pandas as pd
import json
import pyarrow
import ast

# %%
#Se carga el dataset para crear el DataFrame que corresponde 
with open('DB Steam/steam_games.json', 'r') as file:
    data = [json.loads(line) for line in file]

dataGames = pd.json_normalize(data)
dfGames = pd.DataFrame(dataGames)

# %%
dfGames
# Out:
#               publisher                                 genres  \
# 0                   NaN                                    NaN
# 1                   NaN                                    NaN
# 2                   NaN                                    NaN
# 3                   NaN                                    NaN
# 4                   NaN                                    NaN
# ...                 ...                                    ...
# 120440  Ghost_RUS Games  [Casual, Indie, Simulation, Strategy]
# 120441           Sacada              [Casual, Indie, Strategy]
# 120442     Laush Studio            [Indie, Racing, Simulation]
# 120443         SIXNAILS                        [Casual, Indie]
# 120444              NaN                                    NaN
#
#                         app_name                     title  \
# 0                            NaN                       NaN
# 1                            NaN                       NaN
# ...

# %%
#Se eliminan las filas que se encuentren vacias, y también algunas columnas que no son necesarias para este caso
dfGames = dfGames.dropna(how = 'all')
dfGames.drop(['app_name','early_access','url','reviews_url','tags','publisher','specs'], axis=1, inplace = True)
dfGames.reindex()
# Out:
# /var/folders/47/k8p8b34120x38zvvxtyv0l6c0000gn/T/ipykernel_1161/3143255271.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfGames.drop(['app_name','early_access','url','reviews_url','tags','publisher','specs'], axis=1, inplace = True)
#                                                    genres  \
# 88310       [Action, Casual, Indie, Simulation, Strategy]
# 88311                [Free to Play, Indie, RPG, Strategy]
# 88312   [Casual, Free to Play, Indie, Simulation, Sports]
# 88313                         [Action, Adventure, Casual]
# 88314                                                 NaN
# ...                                                   ...
# 120440              [Casual, Indie, Simulation, Strategy]
# 120441                          [Casual, Indie, Strategy]
# ...

# %%
#Se extrae solamente el año de la columna 'release_date' en una nueva columna cambiando el tipo de dato a int
dfGames['release_date'] = pd.to_datetime(dfGames['release_date'], format = 'mixed', errors = 'coerce')
dfGames['release_year'] = dfGames['release_date'].dt.year.fillna(0).astype(int)
# Out:
# /var/folders/47/k8p8b34120x38zvvxtyv0l6c0000gn/T/ipykernel_1161/2856379860.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfGames['release_date'] = pd.to_datetime(dfGames['release_date'], format = 'mixed', errors = 'coerce')
# /var/folders/47/k8p8b34120x38zvvxtyv0l6c0000gn/T/ipykernel_1161/2856379860.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfGames['release_year'] = dfGames['release_date'].dt.year.fillna(0).astype(int)

# %%
dfGames.head()
# Out:
#                                                   genres  \
# 88310      [Action, Casual, Indie, Simulation, Strategy]
# 88311               [Free to Play, Indie, RPG, Strategy]
# 88312  [Casual, Free to Play, Indie, Simulation, Sports]
# 88313                        [Action, Adventure, Casual]
# 88314                                                NaN
#
#                          title release_date         price      id  \
# 88310      Lost Summoner Kitty   2018-01-04          4.99  761140
# 88311                Ironbound   2018-01-04  Free To Play  643980
# 88312  Real Pool 3D - Poolians   2017-07-24  Free to Play  670290
# 88313                  弹炸人2222   2017-12-07          0.99  767400
# 88314                      NaN          NaT          2.99  773570
#
#               developer  release_year
# 88310         Kotoshiro          2018
# 88311  Secret Level SRL          2018
# 88312      Poolians.com          2017
# 88313              彼岸领域          2017
# ...

# %%
#Se puede observar que en la columna price hay diferentes tipos de datos
dfGames['price'].apply(type).unique()
# Out:
# array([<class 'float'>, <class 'str'>], dtype=object)

# %%
#Se lista cuales son los valores tipo str de la columna price
dfGames['price'].loc[dfGames['price'].apply(type) == str].unique()
# Out:
# array(['Free To Play', 'Free to Play', 'Free', 'Free Demo',
#        'Play for Free!', 'Install Now', 'Play WARMACHINE: Tactics Demo',
#        'Free Mod', 'Install Theme', 'Third-party', 'Play Now',
#        'Free HITMAN™ Holiday Pack', 'Play the Demo',
#        'Starting at $499.00', 'Starting at $449.00', 'Free to Try',
#        'Free Movie', 'Free to Use'], dtype=object)

# %%
'''Como queremos saber los precios por año, entonces cambiamos los valores de la columna
price que nos indiquen que son gratis al valor de 0 y los que son pagos, a su valor correspondiente'''
dfGames.loc[dfGames['price'].str.contains('Free', case = False) & dfGames['price'].notna(), 'price'] = 0.0
dfGames.loc[dfGames['price'].str.contains('install', case = False) & dfGames['price'].notna(), 'price'] = 0.0
dfGames.loc[dfGames['price'].str.contains('play', case = False) & dfGames['price'].notna(), 'price'] = 0.0
dfGames.loc[dfGames['price'].str.contains('third', case = False) & dfGames['price'].notna(), 'price'] = 0.0
dfGames.loc[dfGames['price'].str.contains('449', case = False) & dfGames['price'].notna(), 'price'] = 449.0
dfGames.loc[dfGames['price'].str.contains('499', case = False) & dfGames['price'].notna(), 'price'] = 499.0

# %%
dfGames['price'].apply(type).unique()
#Ya podemos ver que no hay valores de tipo str
# Out:
# array([<class 'float'>], dtype=object)

# %%
#Se cambia el nombre de la columna 'id' a 'item_id' para poder relacionar con los otros datasets
dfGames = dfGames.rename(columns = {'id': 'item_id'})

# %%
dfGames
# Out:
#                                                    genres  \
# 88310       [Action, Casual, Indie, Simulation, Strategy]
# 88311                [Free to Play, Indie, RPG, Strategy]
# 88312   [Casual, Free to Play, Indie, Simulation, Sports]
# 88313                         [Action, Adventure, Casual]
# 88314                                                 NaN
# ...                                                   ...
# 120440              [Casual, Indie, Simulation, Strategy]
# 120441                          [Casual, Indie, Strategy]
# 120442                        [Indie, Racing, Simulation]
# 120443                                    [Casual, Indie]
# 120444                                                NaN
#
#                            title release_date price item_id  \
# 88310        Lost Summoner Kitty   2018-01-04  4.99  761140
# 88311                  Ironbound   2018-01-04   0.0  643980
# 88312    Real Pool 3D - Poolians   2017-07-24   0.0  670290
# ...

# %%
#En este punto se transforma el dataframe a un formato parquet
dfGames.to_parquet('DB Steam/steam_games.parquet', index = False)

# %%
dfGames.head()
# Out:
#                                                   genres  \
# 88310      [Action, Casual, Indie, Simulation, Strategy]
# 88311               [Free to Play, Indie, RPG, Strategy]
# 88312  [Casual, Free to Play, Indie, Simulation, Sports]
# 88313                        [Action, Adventure, Casual]
# 88314                                                NaN
#
#                          title release_date price item_id         developer  \
# 88310      Lost Summoner Kitty   2018-01-04  4.99  761140         Kotoshiro
# 88311                Ironbound   2018-01-04   0.0  643980  Secret Level SRL
# 88312  Real Pool 3D - Poolians   2017-07-24   0.0  670290      Poolians.com
# 88313                  弹炸人2222   2017-12-07  0.99  767400              彼岸领域
# 88314                      NaN          NaT  2.99  773570               NaN
#
#        release_year
# 88310          2018
# 88311          2018
# 88312          2017
# 88313          2017
# 88314             0

# %%
# Se crea un dataframe que contenga unicamente el Id de los juegos y también su precio.
dfGamesPrice = dfGames[['item_id', 'price']]
dfGamesPrice.head()
# Out:
#       item_id price
# 88310  761140  4.99
# 88311  643980   0.0
# 88312  670290   0.0
# 88313  767400  0.99
# 88314  773570  2.99

# %%
dfGamesPrice.head(20)
# Out:
#       item_id  price
# 88310  761140   4.99
# 88311  643980    0.0
# 88312  670290    0.0
# 88313  767400   0.99
# 88314  773570   2.99
# 88315  772540   3.99
# 88316  774276   9.99
# 88317  774277  18.99
# 88318  774278  29.99
# 88319  768800    NaN
# 88320  768570    NaN
# 88321  724910    0.0
# 88322  770380  10.99
# 88323  768880   3.99
# 88324  765320   2.99
# 88325  773650   1.59
# 88326  774271  14.99
# 88327  773690   1.99
# 88328  774279  59.99
# 88329  772590   4.99

# %%
# Podemos ver que hay valores del precio que son nulos, así que se eliminarán
dfGamesPrice = dfGamesPrice.dropna(subset = 'price')
dfGamesPrice.head(20)
# Out:
#       item_id  price
# 88310  761140   4.99
# 88311  643980    0.0
# 88312  670290    0.0
# 88313  767400   0.99
# 88314  773570   2.99
# 88315  772540   3.99
# 88316  774276   9.99
# 88317  774277  18.99
# 88318  774278  29.99
# 88321  724910    0.0
# 88322  770380  10.99
# 88323  768880   3.99
# 88324  765320   2.99
# 88325  773650   1.59
# 88326  774271  14.99
# 88327  773690   1.99
# 88328  774279  59.99
# 88329  772590   4.99
# 88330  640250   2.99
# 88331  768060   0.99

# %%
# Se transforma el dataframe creado a formato parquet
dfGamesPrice.to_parquet('DB Steam/GamesPrice.parquet', index = False)

# %%
# Se crea un dataframe que contenga los generos de los juegos junto con su 'item_id'
dfGamesGenre = dfGames[['item_id', 'genres', 'release_year']]
dfGamesGenre.head()
# Out:
#       item_id                                             genres  release_year
# 88310  761140      [Action, Casual, Indie, Simulation, Strategy]          2018
# 88311  643980               [Free to Play, Indie, RPG, Strategy]          2018
# 88312  670290  [Casual, Free to Play, Indie, Simulation, Sports]          2017
# 88313  767400                        [Action, Adventure, Casual]          2017
# 88314  773570                                                NaN             0

# %%
# Podemos ver que hay valores NaN en la columna 'genres', así que se eliminan los juegos que no tengan especificado su genero
dfGamesGenre = dfGamesGenre.dropna(subset = 'genres')

# %%
dfGamesGenre.head(20)
# Out:
#       item_id                                             genres  release_year
# 88310  761140      [Action, Casual, Indie, Simulation, Strategy]          2018
# 88311  643980               [Free to Play, Indie, RPG, Strategy]          2018
# 88312  670290  [Casual, Free to Play, Indie, Simulation, Sports]          2017
# 88313  767400                        [Action, Adventure, Casual]          2017
# 88315  772540                    [Action, Adventure, Simulation]          2018
# 88316  774276          [Free to Play, Indie, Simulation, Sports]          2018
# 88317  774277          [Free to Play, Indie, Simulation, Sports]          2018
# 88318  774278          [Free to Play, Indie, Simulation, Sports]          2018
# 88319  768800                [Casual, Indie, Racing, Simulation]          2018
# 88320  768570          [Action, Indie, Simulation, Early Access]             0
# 88322  770380            [Action, Adventure, Casual, Indie, RPG]          2018
# ...

# %%
# Se hace una comprensión de lista que cambia cada elemento '&' por 'and' en la columna 'genres'
dfGamesGenre['genres'] = dfGamesGenre['genres'].apply(lambda x: [element.replace('&amp;', 'and') for element in x]) 
dfGamesGenre.head()
# Out:
#       item_id                                             genres  release_year
# 88310  761140      [Action, Casual, Indie, Simulation, Strategy]          2018
# 88311  643980               [Free to Play, Indie, RPG, Strategy]          2018
# 88312  670290  [Casual, Free to Play, Indie, Simulation, Sports]          2017
# 88313  767400                        [Action, Adventure, Casual]          2017
# 88315  772540                    [Action, Adventure, Simulation]          2018

# %%
# Seguidamente se transforma el dataframe a formato parquet 
dfGamesGenre.to_parquet('DB Steam/GamesGenre.parquet', index = False)

# %%
# Se desanidan los datos de la columna 'genres' que estan anidados en listas con el método explode.
dfGamesGenre_sep = dfGamesGenre.explode('genres').reset_index(drop = True)
dfGamesGenre_sep.head()
# Out:
#   item_id      genres  release_year
# 0  761140      Action          2018
# 1  761140      Casual          2018
# 2  761140       Indie          2018
# 3  761140  Simulation          2018
# 4  761140    Strategy          2018

# %%
# Convertimos el dataframe con los generos desanidados a formato parquet
dfGamesGenre_sep.to_parquet('DB Steam/GamesGenre_sep.parquet', index = False)

# %%
# Se crea un dataframe con la información de los desarrolladores de los juegos.
# También se eliminan los juegos que no tengan especificado su desarrollador.
dfGamesDevs = dfGames[['item_id', 'developer','release_year']]
dfGamesDevs = dfGamesDevs.dropna(subset = 'developer')
dfGamesDevs.head()
# Out:
#       item_id            developer  release_year
# 88310  761140            Kotoshiro          2018
# 88311  643980     Secret Level SRL          2018
# 88312  670290         Poolians.com          2017
# 88313  767400                 彼岸领域          2017
# 88315  772540  Trickjump Games Ltd          2018

# %%
# Lo convertimos a parquet como todos los anteriores 
dfGamesDevs.to_parquet('DB Steam/GamesDevs.parquet', index = False)
